# %% [markdown]
# # Módulo Deep Learning
# ## Actividad 2: Reinforcement Learning: **Frozen lake problem**

# %% [markdown]
# GRUPO 7
#
# Alina Oganesyan
# Celia Vincent
# Orlando Dotollo

# %% [markdown]
# # Actividad Reinforcemente Learning
#
# Resolver el problema del Frozen lake de OpenAI Gym. Documentación: https://www.gymlibrary.dev/environments/toy_text/frozen_lake/
#
# ## Objetivos
# - Conseguir movermos aleatoriamente hasta cumplir el objetivo
# - Conseguir que el agente aprenda con Q-learning
# - (Opcional) Probar con otros hiperparámetros
# - (Opcional) Modificar la recompensa
#
# ## Consideraciones
# - No hay penalizaciones
# - Si el agente cae en un "hole", entonces done = True y se queda atascado sin poder salir (al igual que ocurre cuando llega al "goal")
#
# ## Normas a seguir
#
# - Se debe entregar un **ÚNICO GOOGLE COLAB notebook** (archivo .ipynb) que incluya las instrucciones presentes y su **EJECUCIÓN!!!**.
# - Poner el nombre del grupo en el nombre del archivo y el nombre de todos los integrantes del grupo al inicio del notebook.
#
# ## Criterio de evaluación
#
# - Seguimiento de las normas establecidas en la actividad.
# - Corrección en el uso de algoritmos, modelos y formas idiomáticas en Python.
# - El código debe poder ejecutarse sin modificación alguna en Google Colaboratory.

# %% [markdown]
# ## **Instalamos librerías**

# %%
# !pip install gym==0.17.3
# !pip install numpy==1.23.5

# %%
import gym
import numpy as np
from time import sleep
from IPython.display import clear_output
import random as rd

# %% [markdown]
# ## **Definición del entorno**

# %% [markdown]
# ![GIF Animado](https://www.gymlibrary.dev/_images/frozen_lake.gif)

# %%
# Definimos el entorno
env = gym.make('FrozenLake-v0', desc=None, map_name="4x4", is_slippery=False)

# %%
# Fijamos una semilla
seed_value = 42
env.seed(seed_value)
np.random.seed(seed_value)

# %%
env.reset() # En este caso, empieza desde la misma posición inicial
print(env.render())
# Out:
# SFFF
# FHFH
# FFFH
# HFFG
# None

# %%
print("Action Space {}".format(env.action_space))
print("State Space {}".format(env.observation_space))
# Out:
# Action Space Discrete(4)
# State Space Discrete(16)

# %% [markdown]
# Acciones posibles:
# * 0: izquierda
# * 1: abajo
# * 2: derecha
# * 3: arriba

# %%
# Identificador de estado
state = env.s
print("State:", state)
# Out:
# State: 0

# %% [markdown]
# ## **Comprobamos las acciones.**

# %%
# Posición inicial
steps = 0
env.reset()
env.render()
# Out:
# SFFF
# FHFH
# FFFH
# HFFG

# %%
# Acciones: 0=izquierda, 1=abajo, 2=derecha, 3=arriba

action = 1 # abajo
state, reward, done, info = env.step(action)

print("State:", state)

env.s = state
env.render()

steps += 1

print(f"Step: {steps}")
# Out:
# State: 4
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 1

# %%
action = 3 # arriba
state, reward, done, info = env.step(action)
print("State:", state)
env.s = state
env.render()
steps += 1
print(f"Step: {steps}")
# Out:
# State: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 2

# %%
action = 2 # derecha
state, reward, done, info = env.step(action)
print("State:", state)
env.s = state
env.render()
steps += 1
print(f"Step: {steps}")
# Out:
# State: 1
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 3

# %%
action = 0 # izquierda
state, reward, done, info = env.step(action)
print("State:", state)
env.s = state
env.render()
steps += 1
print(f"Step: {steps}")
# Out:
# State: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 4

# %% [markdown]
# ## **¡Nos movemos aleatoriamente!**

# %% [markdown]
# Le decimos que haga 10 acciones de forma aleatoria desde el estado inicial y le fijamos un contador de las iteraciones de tiempo, penalzaciónes y victorias. Iniciamos con los contadores a cero.
#
# Para movernos aleatoriamente usamos .env_action_space.sample() y esto se lo pasamos a env.step
#
# Almacenamos los resultados generados en cada acción.

# %%
state = env.reset()
print(f'Initial state: {state}')

timestep = 0
victories = 0

for num_paso in range(10):

  action = env.action_space.sample() # con "sample" elegimos una de las acciones del action_space al azar
  state, reward, done, info = env.step(action) # con "step" realizamos la acción elegida

  timestep += 1

  # Visualizamos el estado actual del entorno
  env.render()
  print(f"Step: {timestep}, Action: {action}, state: {state}, Reward: {reward}, Done: {done}")
  print("-" * 55)  # Línea de separación
  
  if done:
    if reward == 1:
      victories += 1 # si llegamos al objetivo, sumamos 1 al contador de victorias
      print('\033[1m¡VICTORIA!\033[0m')  # Texto en negrita
      break
    else:
      print('\033[1m¡Oh!Caíste en un agujero. Iniciando...\033[0m')  # Texto en negrita
    break

print("Pasos dados: {}".format(timestep))
print("Victories: {}".format(victories))
print('Estado final:', state)
env.render() # visualizamos el estado final
# Out:
# Initial state: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 1, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 2, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 3, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 4, Action: 2, state: 9, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 5, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 6, Action: 1, state: 12, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh!Caíste en un agujero. Iniciando...
# Pasos dados: 6
# Victories: 0
# Estado final: 12
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG

# %% [markdown]
# ## **Nos movemos aleatoriamente hasta el goal.**

# %%
class bcolors:
    RED = '\u001b[31m'
    GREEN = '\u001b[32m'
    RESET = '\u001b[0m'

# Reiniciamos el entorno para comenzar un nuevo episodio
state = env.reset()
print(f'Initial state: {state}')

# Inicializamos las variables
timestep = 0
victories = 0

while victories == 0:
    # Reiniciamos el entorno para comenzar un nuevo episodio
    state = env.reset()
    print(f'Initial state: {state}')

    while True:
        action = env.action_space.sample()  # Elegimos una acción al azar. 0=izquierda, 1=abajo, 2=derecha, 3=arriba
        state, reward, done, info = env.step(action)  # Realizamos la acción elegida

        timestep += 1  # Incrementamos el contador de pasos

        # Visualizamos el estado actual del entorno
        env.render()
        print(f'Step: {timestep}, Action: {action}, state: {state}, Reward: {reward}, Done: {done}')
        print('-' * 55)  # Línea de separación

        if done:
            if reward == 1:
                victories += 1  # Incrementamos el contador de victorias si se alcanza el objetivo
                print(f'{bcolors.GREEN}\033[1m¡VICTORIA!\033[0m{bcolors.RESET}')  # Texto verde y en negrita
                break
            else:
                print(f'{bcolors.RED}\033[1m¡Oh! Caíste en un agujero. Iniciando...\033[0m{bcolors.RESET}')  # Texto rojo y en negrita
            break

print('Pasos dados: {}'.format(timestep))
print('Victories: {}'.format(victories))
print('Estado final:', state)
env.render()  # Visualizamos el estado final
# Out:
# Initial state: 0
# Initial state: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 1, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 2, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 3, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 4, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 5, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 6, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 7, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 8, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 9, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 10, Action: 2, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 11, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 12, Action: 0, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 13, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 14, Action: 3, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 15, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 16, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 17, Action: 2, state: 2, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 18, Action: 1, state: 6, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 19, Action: 1, state: 10, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 20, Action: 1, state: 14, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 21, Action: 1, state: 14, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 22, Action: 3, state: 10, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 23, Action: 3, state: 6, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 24, Action: 1, state: 10, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 25, Action: 3, state: 6, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 26, Action: 0, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 27, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 28, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 29, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 30, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 31, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 32, Action: 0, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 33, Action: 2, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 34, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 35, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 36, Action: 1, state: 12, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 37, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 38, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 39, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 40, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 41, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 42, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 43, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 44, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 45, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 46, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 47, Action: 2, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 48, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 49, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 50, Action: 1, state: 12, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 51, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 52, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 53, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 54, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 55, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 56, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 57, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 58, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 59, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 60, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 61, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 62, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 63, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 64, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 65, Action: 0, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 66, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 67, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 68, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 69, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 70, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 71, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 72, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 73, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 74, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 75, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 76, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 77, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 78, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 79, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 80, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 81, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 82, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 83, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 84, Action: 2, state: 9, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 85, Action: 2, state: 10, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 86, Action: 1, state: 14, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 87, Action: 3, state: 10, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 88, Action: 1, state: 14, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 89, Action: 3, state: 10, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 90, Action: 0, state: 9, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 91, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 92, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 93, Action: 2, state: 9, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 94, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 95, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 96, Action: 1, state: 12, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 97, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 98, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 99, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 100, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 101, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 102, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 103, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 104, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 105, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 106, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 107, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 108, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 109, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 110, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 111, Action: 2, state: 9, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 112, Action: 3, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 113, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 114, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 115, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 116, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 117, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 118, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 119, Action: 2, state: 2, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 120, Action: 0, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 121, Action: 2, state: 2, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 122, Action: 1, state: 6, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 123, Action: 3, state: 2, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 124, Action: 0, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 125, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 126, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 127, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 128, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 129, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 130, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 131, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 132, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 133, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 134, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 135, Action: 2, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 136, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 137, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 138, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 139, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 140, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 141, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 142, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 143, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 144, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 145, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 146, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 147, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 148, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 149, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 150, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 151, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 152, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 153, Action: 3, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 154, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 155, Action: 3, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 156, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 157, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 158, Action: 3, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 159, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 160, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 161, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 162, Action: 2, state: 9, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 163, Action: 3, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 164, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 165, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 166, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 167, Action: 0, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 168, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 169, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 170, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 171, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 172, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 173, Action: 3, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 174, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 175, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 176, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 177, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 178, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 179, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 180, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 181, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 182, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 183, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 184, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 185, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 186, Action: 2, state: 9, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 187, Action: 3, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 188, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 189, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 190, Action: 2, state: 2, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 191, Action: 0, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 192, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 193, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 194, Action: 2, state: 2, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 195, Action: 0, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 196, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 197, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 198, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 199, Action: 3, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 200, Action: 0, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 201, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 202, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 203, Action: 2, state: 9, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 204, Action: 2, state: 10, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 205, Action: 2, state: 11, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 206, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 207, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 208, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 209, Action: 0, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 210, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 211, Action: 3, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 212, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 213, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 214, Action: 3, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 215, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 216, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 217, Action: 2, state: 9, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 218, Action: 1, state: 13, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 219, Action: 2, state: 14, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 220, Action: 1, state: 14, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 221, Action: 0, state: 13, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 222, Action: 1, state: 13, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 223, Action: 1, state: 13, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 224, Action: 3, state: 9, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 225, Action: 2, state: 10, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 226, Action: 2, state: 11, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 227, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 228, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 229, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 230, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 231, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 232, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 233, Action: 1, state: 12, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 234, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 235, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 236, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 237, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 238, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 239, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 240, Action: 2, state: 2, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 241, Action: 2, state: 3, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 242, Action: 1, state: 7, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 243, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 244, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 245, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 246, Action: 2, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 247, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 248, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 249, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 250, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 251, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 252, Action: 2, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 253, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 254, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 255, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 256, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 257, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 258, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 259, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 260, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 261, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 262, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 263, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 264, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 265, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 266, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 267, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 268, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 269, Action: 2, state: 2, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 270, Action: 2, state: 3, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 271, Action: 1, state: 7, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 272, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 273, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 274, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 275, Action: 2, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 276, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 277, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 278, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 279, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 280, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 281, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 282, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 283, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 284, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 285, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 286, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 287, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 288, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 289, Action: 2, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 290, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 291, Action: 2, state: 2, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 292, Action: 2, state: 3, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 293, Action: 0, state: 2, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 294, Action: 0, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 295, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 296, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 297, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 298, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 299, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 300, Action: 3, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 301, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 302, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 303, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 304, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 305, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 306, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 307, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 308, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 309, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 310, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 311, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 312, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 313, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 314, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 315, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 316, Action: 1, state: 12, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 317, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 318, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 319, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 320, Action: 2, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 321, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 322, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 323, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 324, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 325, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ...
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 398, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 399, Action: 2, state: 2, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 400, Action: 1, state: 6, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 401, Action: 0, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 402, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 403, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 404, Action: 2, state: 2, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 405, Action: 2, state: 3, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 406, Action: 2, state: 3, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 407, Action: 1, state: 7, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 408, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 409, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 410, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 411, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 412, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 413, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 414, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 415, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 416, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 417, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 418, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 419, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 420, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 421, Action: 0, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 422, Action: 2, state: 9, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 423, Action: 3, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 424, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 425, Action: 2, state: 2, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 426, Action: 3, state: 2, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 427, Action: 1, state: 6, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 428, Action: 0, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 429, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 430, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 431, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 432, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 433, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 434, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 435, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 436, Action: 3, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 437, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 438, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 439, Action: 0, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 440, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 441, Action: 1, state: 12, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 442, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 443, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 444, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 445, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 446, Action: 2, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 447, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 448, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 449, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 450, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 451, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 452, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 453, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 454, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 455, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 456, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 457, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 458, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 459, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 460, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 461, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 462, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 463, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 464, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 465, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 466, Action: 0, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 467, Action: 0, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 468, Action: 0, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 469, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 470, Action: 1, state: 12, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 471, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 472, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 473, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 474, Action: 0, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 475, Action: 2, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 476, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 477, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 478, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 479, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 480, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 481, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 482, Action: 3, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 483, Action: 0, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 484, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 485, Action: 3, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 486, Action: 2, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 487, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 488, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 489, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 490, Action: 2, state: 1, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 491, Action: 1, state: 5, Reward: 0.0, Done: True
# -------------------------------------------------------
# ¡Oh! Caíste en un agujero. Iniciando...
# Initial state: 0
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 492, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 493, Action: 0, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 494, Action: 3, state: 0, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 495, Action: 1, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 496, Action: 0, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 497, Action: 0, state: 4, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 498, Action: 1, state: 8, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 499, Action: 2, state: 9, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 500, Action: 2, state: 10, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 501, Action: 1, state: 14, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 502, Action: 1, state: 14, Reward: 0.0, Done: False
# -------------------------------------------------------
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Step: 503, Action: 2, state: 15, Reward: 1.0, Done: True
# -------------------------------------------------------
# ¡VICTORIA!
# Pasos dados: 503
# Victories: 1
# Estado final: 15
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG

# %% [markdown]
# ## Q-learning: train

# %%
q_table = np.zeros([env.observation_space.n, env.action_space.n])

# %%
q_table[0]

# %%
#trade-off entre explorar y explotar: epsilon
def greedy_trade_off(epsilon, q_table, state, env):
  if rd.random() < epsilon:
    action = env.action_space.sample() #explorar
  else:
    action = np.argmax(q_table[state]) #explotar
  return action

# %%
# Hyperparameters
alpha = 0.2 # tasa de aprendizaje
gamma = 0.7 # tasa de descuento
epsilon = 0.15 # greedy policy

# For plotting metrics
all_timestep = []
all_penalties = []

episodes = 100000

q_table = np.zeros([env.observation_space.n, env.action_space.n])

for i in range(episodes):
  state = env.reset()

  timestep, penalties = 0, 0
  done = False

  while not done and reward !=0:
    action = greedy_trade_off(epsilon, q_table, state, env) # aplicamos la greedy policy

    next_state, reward, done, info = env.step(action) # tomamos la acción elegida

    old_value = q_table[state, action] # en la Q-table, tomamos el valor Q de la acción elegida para el estado actual
    next_max = np.max(q_table[next_state]) # en la Q-table, tomamos el máximo entre los valores Q para el nuevo estado

    new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max) # actualizamos el valor Q
    q_table[state, action] = new_value

    if reward == -10:
      penalties += 1

    state = next_state

  if i % 100 == 0:
    clear_output(wait=True)
    print(f"Episodio: {i+1}")

  timestep += 1

clear_output(wait=True)
print(f"Episodio: {i+1}")
print("¡Entrenamiento finalizado!")

# %%
q_table[0]

# %% [markdown]
# ## Prueba de CHATGPT

# %% [markdown]
# Inicializar la tabla Q con ceros.
# Para cada episodio:
# Inicializar el estado S.
# Mientras el episodio no termine:
# Elegir una acción A desde el estado S usando la política derivada de Q (por ejemplo, ε-greedy).
# Tomar la acción A, observar el nuevo estado S' y la recompensa R.
# Actualizar la tabla Q usando la ecuación de Bellman: Q(S,A) = Q(S,A) + α * (R + γ * max(Q(S',a)) - Q(S,A))
# S = S'.
# Repetir el proceso para el número deseado de episodios.
# Código en Python:

# %%
# Inicializar la tabla Q
Q = np.zeros([env.observation_space.n, env.action_space.n])

# Parámetros del aprendizaje
alpha = 0.8  # Tasa de aprendizaje
gamma = 0.95  # Factor de descuento
num_episodes = 2000  # Número de episodios

# Proceso de aprendizaje
for i in range(num_episodes):
    # Resetear el entorno y obtener el primer estado
    state = env.reset()
    done = False

    while not done:
        # Elegir una acción por la política ε-greedy
        if np.random.rand() < (1 - (i / num_episodes)):
            action = env.action_space.sample()
        else:
            action = np.argmax(Q[state, :])

        # Tomar la acción y obtener el nuevo estado y recompensa
        new_state, reward, done, _ = env.step(action)

        # Actualizar Q
        Q[state, action] = Q[state, action] + alpha * (reward + gamma * np.max(Q[new_state, :]) - Q[state, action])

        # Actualizar el estado
        state = new_state

# Imprimir la tabla Q aprendida
print("Tabla Q aprendida:")
print(Q)
